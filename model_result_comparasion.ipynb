# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Bangkit/artnesia/modelling/'
# Out:
# /content/drive/MyDrive/Bangkit/artnesia/modelling

# %%
ls
# Out:
#  arnesia_super_simple_version.tflite
#  artnesia2.tflite
#  artnesia_compressed2.tflite
#  artnesia_compressed.tflite
#  artnesia.tflite
#  ArtnesiaTfLiteModelling.ipynb
#  best_model2.h5
#  best_model.h5
# 'Compress the model.ipynb'
# 'Copy of ArtnesiaTfLiteModelling.ipynb'
#  dataset/
# 'Modelling using TFLite Model Maker.ipynb'
#  model_result_comparasion.ipynb
#  test/
#  train/
#  val/

# %%
import tensorflow as tf
model1 = tf.keras.models.load_model('best_model.h5')
model2 = tf.keras.models.load_model('best_model2.h5')

# %%
#comparassion score
model1 = list()
model2 = list()

# %%
labels = train_generator.class_indices.keys()
uploaded = files.upload()

for paths in uploaded.keys():
 
  # predicting images
  path = paths
  img = image.load_img(path, target_size=(224, 224))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  images = np.vstack([x])
  proba = model2.predict(images)[0]
  plt.imshow(img)
  plt.show()
  print(model2.predict(images))
  for (label, p) in zip(labels, proba):
    print("{}: {:.2f}%".format(label, p * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c0ca071b5659> in <module>()
# ----> 1 labels = train_generator.class_indices.keys()
#       2 uploaded = files.upload()
#       3
#       4 for paths in uploaded.keys():
#       5
#
# NameError: name 'train_generator' is not defined
