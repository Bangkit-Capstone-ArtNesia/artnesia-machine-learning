# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Bangkit/artnesia/modelling/'
# Out:
# /content/drive/MyDrive/Bangkit/artnesia/modelling

# %%
ls
# Out:
#  artnesia.tflite                          test/
#  ArtnesiaTfLiteModelling.ipynb            train/
#  best_model.h5                            Untitled0.ipynb
# 'Copy of ArtnesiaTfLiteModelling.ipynb'   val/
#  dataset/

# %%
import tensorflow as tf
model = tf.keras.models.load_model('best_model.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_quant_model = converter.convert()
open("artnesia_compressed.tflite", "wb").write(tflite_quant_model)
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpwalm8fj0/assets
# INFO:tensorflow:Assets written to: /tmp/tmpwalm8fj0/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 61924416

# %%
import tensorflow as tf
model = tf.keras.models.load_model('best_model2.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_quant_model = converter.convert()
open("artnesia_compressed2.tflite", "wb").write(tflite_quant_model)
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpdbum9sv3/assets
# INFO:tensorflow:Assets written to: /tmp/tmpdbum9sv3/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 61923520
