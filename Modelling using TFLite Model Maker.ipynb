# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Bangkit/artnesia/modelling/'
# Out:
# /content/drive/MyDrive/Bangkit/artnesia/modelling

# %%
cd ..
# Out:
# /content/drive/MyDrive/Bangkit/artnesia/modelling

# %%
ls
# Out:
# angklung/           blangkon/  noken/          wayang_gareng/
# batik_bali/         ganongan/  sasando/        wayang_petruk/
# batik_cendrawasih/  keris/     wayang_bagong/  wayang_semar/

# %%
# !pip install -q tflite-model-maker
# Out:
#      |████████████████████████████████| 642 kB 15.5 MB/s
#      |████████████████████████████████| 6.4 MB 50.3 MB/s
#      |████████████████████████████████| 77 kB 6.8 MB/s
#      |████████████████████████████████| 42.5 MB 1.2 MB/s
#      |████████████████████████████████| 87 kB 9.0 MB/s
#      |████████████████████████████████| 1.2 MB 44.8 MB/s
#      |████████████████████████████████| 1.1 MB 70.1 MB/s
#      |████████████████████████████████| 10.9 MB 52.6 MB/s
#      |████████████████████████████████| 237 kB 57.5 MB/s
#      |████████████████████████████████| 3.4 MB 63.1 MB/s
#      |████████████████████████████████| 840 kB 51.0 MB/s
#      |████████████████████████████████| 596 kB 52.7 MB/s
#      |████████████████████████████████| 120 kB 60.7 MB/s
#      |████████████████████████████████| 25.3 MB 1.3 MB/s
#      |████████████████████████████████| 48.3 MB 90 kB/s
#      |████████████████████████████████| 352 kB 66.7 MB/s
#      |████████████████████████████████| 99 kB 10.4 MB/s
#      |████████████████████████████████| 40 kB 6.4 MB/s
#      |████████████████████████████████| 213 kB 62.8 MB/s
#      |████████████████████████████████| 1.1 MB 57.6 MB/s
#   Building wheel for fire (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
from tflite_model_maker import image_classifier
from tflite_model_maker.image_classifier import DataLoader

import tensorflow as tf
assert tf.__version__.startswith('2')

import matplotlib.pyplot as plt
import numpy as np

# %%
data = DataLoader.from_folder('dataset')
train_data, test_data = data.split(0.9)
# Out:
# INFO:tensorflow:Load image with size: 2905, num_label: 12, labels: angklung, batik_bali, batik_cendrawasih, blangkon, ganongan, keris, noken, sasando, wayang_bagong, wayang_gareng, wayang_petruk, wayang_semar.

# %%
model = image_classifier.create(train_data)
# Out:
# INFO:tensorflow:Retraining the models...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hub_keras_layer_v1v2 (HubKe  (None, 1280)             3413024
#  rasLayerV1V2)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 12)                15372
#
# =================================================================
# Total params: 3,428,396
# Trainable params: 15,372
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 81/81 [==============================] - 272s 3s/step - loss: 1.1495 - accuracy: 0.7666
# Epoch 2/5
# 81/81 [==============================] - 82s 1s/step - loss: 0.7212 - accuracy: 0.9522
# Epoch 3/5
# 81/81 [==============================] - 82s 1s/step - loss: 0.6795 - accuracy: 0.9688
# Epoch 4/5
# 81/81 [==============================] - 83s 1s/step - loss: 0.6579 - accuracy: 0.9776
# Epoch 5/5
# 81/81 [==============================] - 83s 1s/step - loss: 0.6408 - accuracy: 0.9780

# %%
model.export(export_dir='.')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpa6nv7lng/assets
# INFO:tensorflow:Assets written to: /tmp/tmpa6nv7lng/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# INFO:tensorflow:Label file is inside the TFLite model with metadata.
# INFO:tensorflow:Label file is inside the TFLite model with metadata.
# INFO:tensorflow:Saving labels in /tmp/tmpcxevwm3f/labels.txt
# INFO:tensorflow:Saving labels in /tmp/tmpcxevwm3f/labels.txt
# INFO:tensorflow:TensorFlow Lite model exported successfully: ./model.tflite
# INFO:tensorflow:TensorFlow Lite model exported successfully: ./model.tflite

# %%
ls
# Out:
#  artnesia2.tflite               'Copy of ArtnesiaTfLiteModelling.ipynb'
#  artnesia_compressed2.tflite     dataset/
#  artnesia_compressed.tflite     'Modelling using TFLite Model Maker.ipynb'
#  artnesia.tflite                 model_result_comparasion.ipynb
#  ArtnesiaTfLiteModelling.ipynb   model.tflite
#  best_model2.h5                  test/
#  best_model.h5                   train/
# 'Compress the model.ipynb'       val/
